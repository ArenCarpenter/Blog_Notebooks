# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
import math

# %%
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

# %%
domain = np.linspace(-3,3,1000)

plt.figure(figsize=(8,6))

plt.plot(domain, norm.pdf(domain, 0, 1), color = 'firebrick', lw = 3, label = 'Mean = 0 | Stdev = 1')



plt.title('Standard Normal Distribution', fontsize=14)
plt.ylabel('Density')
plt.xlabel('Value')

plt.legend()
plt.show()

# %%
mu1 = 0
variance1 = 1
sigma1 = math.sqrt(variance)
x1 = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)

mu2 = 1
variance2 = 1
sigma2 = math.sqrt(variance)
x2 = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)

mu3 = 2
variance3 = 1
sigma3 = math.sqrt(variance)
x3 = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)

plt.figure(figsize=(10,8))

plt.plot(x, stats.norm.pdf(x1, mu1, sigma1), color = 'darkturquoise', lw=3)
plt.plot(x, stats.norm.pdf(x2, mu2, sigma2), color = 'firebrick', lw=3)
plt.plot(x, stats.norm.pdf(x3, mu3, sigma3), color = 'darkgoldenrod', lw=3)

plt.title('A Normal Distribution')
plt.xlabel('Standard Deviations')
plt.xlim((-4, 4))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-77e1122c7a65> in <module>
#       1 mu1 = 0
#       2 variance1 = 1
# ----> 3 sigma1 = math.sqrt(variance)
#       4 x1 = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
#       5
#
# NameError: name 'variance' is not defined

# %%
domain = np.linspace(-6,6,1000)
plt.figure(figsize=(10,8))

plt.plot(domain, norm.pdf(domain, 0, 1), color = 'firebrick', lw = 3, label = 'Mean = 0 | Stdev = 1')
plt.plot(domain, norm.pdf(domain, 0,0.5), color = 'darkturquoise', label='Mean = 0 | Stdev = 0.5')
plt.plot(domain, norm.pdf(domain, 0, 2), color = 'darkgoldenrod', label = 'Mean = 0 | Stdev = 2')
plt.plot(domain, norm.pdf(domain, 3, 1), color = 'darkblue', label = 'Mean = 2 | Stdev = 1')

plt.suptitle('Some Normal Distributions', y = 0.95, fontsize=14)
plt.title('You can create a normal distribution with just a mean and standard deviation.', fontsize=10)

plt.ylabel('Density')
plt.xlabel('Value')

plt.legend()
plt.show()

# %%
domain = np.linspace(-5,5,1000)

plt.figure(figsize=(8,6))

red = plt.plot(domain, norm.pdf(domain, -1, 1), color = 'firebrick', lw = 3)
blue = plt.plot(domain, norm.pdf(domain, 1, 1), color = 'darkturquoise', lw = 3)
line = plt.vlines(0, ymin=0, ymax=.4)

plt.ylabel('Density')
plt.xlabel('Value')

plt.show()
